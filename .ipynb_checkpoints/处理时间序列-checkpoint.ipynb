# %%
from datetime import datetime
datetime(year=2015,month=7,day=5)
# Out:
# datetime.datetime(2015, 7, 5, 0, 0)

# %%
from dateutil import parser
date = parser.parse("4th of July, 2015")
date
# Out:
# datetime.datetime(2015, 7, 4, 0, 0)

# %%
date.strftime('%A')
# Out:
# 'Saturday'

# %%
import numpy as np
date = np.array('2015-07-04',dtype=np.datetime64)
date
# Out:
# array('2015-07-04', dtype='datetime64[D]')

# %%
date+np.arange(12)
# Out:
# array(['2015-07-04', '2015-07-05', '2015-07-06', '2015-07-07',
#        '2015-07-08', '2015-07-09', '2015-07-10', '2015-07-11',
#        '2015-07-12', '2015-07-13', '2015-07-14', '2015-07-15'],
#       dtype='datetime64[D]')

# %%
np.datetime64('2015-07-04')
# Out:
# numpy.datetime64('2015-07-04')

# %%
np.datetime64('2015-07-04 12:00')
# Out:
# numpy.datetime64('2015-07-04T12:00')

# %%
np.datetime64('2015-07-04 12:59:59.50', 'ns')
# Out:
# numpy.datetime64('2015-07-04T12:59:59.500000000')

# %%
import pandas as pd
date = pd.to_datetime("4th of July, 2015")
date
# Out:
# Timestamp('2015-07-04 00:00:00')

# %%
date.strftime('%A')
# Out:
# 'Saturday'

# %%
date + pd.to_timedelta(np.arange(12),'D')
# Out:
# DatetimeIndex(['2015-07-04', '2015-07-05', '2015-07-06', '2015-07-07',
#                '2015-07-08', '2015-07-09', '2015-07-10', '2015-07-11',
#                '2015-07-12', '2015-07-13', '2015-07-14', '2015-07-15'],
#               dtype='datetime64[ns]', freq=None)

# %%
index = pd.DatetimeIndex(['2014-07-04','2014-08-04','2015-07-04','2015-08-04'])
data = pd.Series([0,1,2,3],index=index)
data
# Out:
# 2014-07-04    0
# 2014-08-04    1
# 2015-07-04    2
# 2015-08-04    3
# dtype: int64

# %%
data['2014-07-04':'2015-07-04']
# Out:
# 2014-07-04    0
# 2014-08-04    1
# 2015-07-04    2
# dtype: int64

# %%
data['2015']
# Out:
# 2015-07-04    2
# 2015-08-04    3
# dtype: int64

# %%
dates = pd.to_datetime([datetime(2015,7,3),'4th of July, 2015','2015-Jul-6','07-07-2015','20150708'])
dates
# Out:
# DatetimeIndex(['2015-07-03', '2015-07-04', '2015-07-06', '2015-07-07',
#                '2015-07-08'],
#               dtype='datetime64[ns]', freq=None)

# %%
dates.to_period('D')
# Out:
# PeriodIndex(['2015-07-03', '2015-07-04', '2015-07-06', '2015-07-07',
#              '2015-07-08'],
#             dtype='period[D]', freq='D')

# %%
dates-dates[0]
# Out:
# TimedeltaIndex(['0 days', '1 days', '3 days', '4 days', '5 days'], dtype='timedelta64[ns]', freq=None)

# %%
pd.date_range('2015-07-03','2015-07-10')
# Out:
# DatetimeIndex(['2015-07-03', '2015-07-04', '2015-07-05', '2015-07-06',
#                '2015-07-07', '2015-07-08', '2015-07-09', '2015-07-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('2015-07-03',periods=8)
# Out:
# DatetimeIndex(['2015-07-03', '2015-07-04', '2015-07-05', '2015-07-06',
#                '2015-07-07', '2015-07-08', '2015-07-09', '2015-07-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('2015-07-03',periods=8,freq='H')
# Out:
# DatetimeIndex(['2015-07-03 00:00:00', '2015-07-03 01:00:00',
#                '2015-07-03 02:00:00', '2015-07-03 03:00:00',
#                '2015-07-03 04:00:00', '2015-07-03 05:00:00',
#                '2015-07-03 06:00:00', '2015-07-03 07:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
pd.period_range('2015-07',periods=8,freq='M')
# Out:
# PeriodIndex(['2015-07', '2015-08', '2015-09', '2015-10', '2015-11', '2015-12',
#              '2016-01', '2016-02'],
#             dtype='period[M]', freq='M')

# %%
pd.timedelta_range(0,periods=10,freq='H')
# Out:
# TimedeltaIndex(['0 days 00:00:00', '0 days 01:00:00', '0 days 02:00:00',
#                 '0 days 03:00:00', '0 days 04:00:00', '0 days 05:00:00',
#                 '0 days 06:00:00', '0 days 07:00:00', '0 days 08:00:00',
#                 '0 days 09:00:00'],
#                dtype='timedelta64[ns]', freq='H')

# %%
pd.timedelta_range(0,periods=9,freq='2H30T')
# Out:
# TimedeltaIndex(['0 days 00:00:00', '0 days 02:30:00', '0 days 05:00:00',
#                 '0 days 07:30:00', '0 days 10:00:00', '0 days 12:30:00',
#                 '0 days 15:00:00', '0 days 17:30:00', '0 days 20:00:00'],
#                dtype='timedelta64[ns]', freq='150T')

# %%
from pandas.tseries.offsets import BDay
pd.date_range('2015-07-01',periods=5,freq=BDay())
# Out:
# DatetimeIndex(['2015-07-01', '2015-07-02', '2015-07-03', '2015-07-06',
#                '2015-07-07'],
#               dtype='datetime64[ns]', freq='B')

# %%
from pandas_datareader import data

goog = data.DataReader('GOOG',start='2004',end='2016',data_source='yahoo')
goog.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2004-08-19  51.835709  47.800831  49.813290  49.982655  44871361.0  49.982655
# 2004-08-20  54.336334  50.062355  50.316402  53.952770  22942874.0  53.952770
# 2004-08-23  56.528118  54.321388  55.168217  54.495735  18342897.0  54.495735
# 2004-08-24  55.591629  51.591621  55.412300  52.239197  15319808.0  52.239197
# 2004-08-25  53.798351  51.746044  52.284027  52.802086   9232276.0  52.802086

# %%
goog = goog['Close']

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn;seaborn.set()

# %%
goog.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
goog.asfreq('BA')
# Out:
# Date
# 2004-12-31     96.035034
# 2005-12-30    206.655411
# 2006-12-29    229.380234
# 2007-12-31    344.448914
# 2008-12-31    153.250580
# 2009-12-31    308.832428
# 2010-12-31    295.875977
# 2011-12-30    321.744019
# 2012-12-31    352.369232
# 2013-12-31    558.262512
# 2014-12-31    524.958740
# 2015-12-31    758.880005
# Freq: BA-DEC, Name: Close, dtype: float64

# %%
goog.plot(alpha=0.5,style='-')
goog.resample('BA').mean().plot(style=':')
goog.asfreq('BA').plot(style='--')
plt.legend(['input','resample','asfreq'],loc='upper left')

# %%
fig, ax = plt.subplots(2,sharex=True)
data = goog.iloc[:10]

data.asfreq('D').plot(ax=ax[0],marker='o')

data.asfreq('D',method='bfill').plot(ax=ax[1],style='-o')
data.asfreq('D',method='ffill').plot(ax=ax[1],style='--o')
ax[1].legend(["back-fill","forward-fill"])

# %%
fig, ax = plt.subplots(3,sharey=True)

goog = goog.asfreq('D',method='pad')

goog.plot(ax=ax[0])
goog.shift(900).plot(ax=ax[1])
goog.tshift(900).plot(ax=ax[2])

local_max = pd.to_datetime('2007-11-05')
offset = pd.Timedelta(900,'D')

ax[0].legend(['input'],loc=2)
ax[0].get_xticklabels()[4].set(weight='heavy',color='red')
ax[0].axvline(local_max,alpha=0.3,color='red')

ax[1].legend(['shift(900)'],loc=2)
ax[1].get_xticklabels()[4].set(weight='heavy',color='red')
ax[1].axvline(local_max+offset,alpha=0.3,color='red')

ax[2].legend(['tshift(900)'],loc=2)
ax[2].get_xticklabels()[1].set(weight='heavy',color='red')
ax[2].axvline(local_max+offset,alpha=0.3,color='red')
# Out:
# <ipython-input-15-fdb839f2a169>:7: FutureWarning: tshift is deprecated and will be removed in a future version. Please use shift instead.
#   goog.tshift(900).plot(ax=ax[2])

# %%
ROI = 100 * (goog.tshift(-365) / goog - 1)
ROI.plot()
plt.ylabel('% Return on Investment')
# Out:
# <ipython-input-16-65517023d101>:1: FutureWarning: tshift is deprecated and will be removed in a future version. Please use shift instead.
#   ROI = 100 * (goog.tshift(-365) / goog - 1)
# Text(0, 0.5, '% Return on Investment')

# %%
rolling = goog.rolling(365,center=True)

data = pd.DataFrame({'input':goog,
                                    'one-year rolling_mean':rolling.mean(),
                                    'one-year rolling_std':rolling.std()})
ax = data.plot(style=['-','--',':'])
ax.lines[0].set_alpha(0.3)

# %%
data = pd.read_csv('Fremont_Bridge_Bicycle_Counter.csv',index_col='Date',parse_dates=True)
data.head()
# Out:
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2019-11-01 00:00:00                  12.0                           7.0
# 2019-11-01 01:00:00                   7.0                           0.0
# 2019-11-01 02:00:00                   1.0                           0.0
# 2019-11-01 03:00:00                   6.0                           6.0
# 2019-11-01 04:00:00                   6.0                           5.0
#
#                      Fremont Bridge West Sidewalk
# Date
# 2019-11-01 00:00:00                           5.0
# 2019-11-01 01:00:00                           7.0
# 2019-11-01 02:00:00                           1.0
# 2019-11-01 03:00:00                           0.0
# 2019-11-01 04:00:00                           1.0

# %%
data.columns = ['Total','East','West']
data.dropna().describe()
# Out:
#                Total           East           West
# count  142864.000000  142864.000000  142864.000000
# mean      111.083716      50.539667      60.544049
# std       141.607196      65.258093      88.019141
# min         0.000000       0.000000       0.000000
# 25%        14.000000       6.000000       7.000000
# 50%        60.000000      28.000000      30.000000
# 75%       145.000000      68.000000      74.000000
# max      1097.000000     698.000000     850.000000

# %%
# %matplotlib inline
import seaborn;seaborn.set()

# %%
data.plot()
plt.ylabel('Hourly Bicycle Count')
# Out:
# Text(0, 0.5, 'Hourly Bicycle Count')

# %%
weekly = data.resample('W').sum()
weekly.plot(style=[':','--','-'])
plt.ylabel('Weekly bicycle count')
# Out:
# Text(0, 0.5, 'Weekly bicycle count')

# %%
daily = data.resample('D').sum()
daily.rolling(30,center=True).mean().plot(style=[':','--','-'])
plt.ylabel('mean of 30 days count')
# Out:
# Text(0, 0.5, 'mean of 30 days count')

# %%
daily
# Out:
#              Total    East    West
# Date
# 2012-10-03  7042.0  3520.0  3522.0
# 2012-10-04  6950.0  3416.0  3534.0
# 2012-10-05  6296.0  3116.0  3180.0
# 2012-10-06  4012.0  2160.0  1852.0
# 2012-10-07  4284.0  2382.0  1902.0
# ...            ...     ...     ...
# 2021-06-26  2173.0   853.0  1320.0
# 2021-06-27  1384.0   567.0   817.0
# 2021-06-28  1209.0   438.0   771.0
# 2021-06-29  2587.0  1075.0  1512.0
# 2021-06-30  3159.0  1285.0  1874.0
#
# [3193 rows x 3 columns]

# %%
daily.rolling(50,center=True,win_type='gaussian').sum(std=10).plot(style=[':','--','-'])
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
by_time = data.groupby(data.index.time).mean()
by_time
# Out:
#                Total        East        West
# 00:00:00   11.009909    4.649311    6.360598
# 01:00:00    5.811051    2.590695    3.220356
# 02:00:00    3.812626    1.823064    1.989562
# 03:00:00    2.814243    1.445583    1.368660
# 04:00:00    6.382432    3.348001    3.034431
# 05:00:00   25.063487   15.183070    9.880417
# 06:00:00   87.502015   52.165435   35.336580
# 07:00:00  219.902586  135.614881   84.287706
# 08:00:00  311.188949  182.205072  128.983876
# 09:00:00  183.342910   98.694388   84.648522
# 10:00:00   99.314180   51.484039   47.830141
# 11:00:00   89.551075   46.079301   43.471774
# 12:00:00   95.966398   48.347782   47.618616
# 13:00:00  102.842963   50.880752   51.962210
# 14:00:00  112.313455   53.389048   58.924408
# 15:00:00  142.023518   62.913825   79.109693
# 16:00:00  230.101125   82.921552  147.179573
# 17:00:00  379.158576  110.726692  268.431883
# 18:00:00  258.386360   87.871997  170.514363
# 19:00:00  128.184949   48.816395   79.368554
# 20:00:00   73.626407   29.954645   43.671762
# 21:00:00   46.940534   20.451369   26.489165
# 22:00:00   30.545271   13.123635   17.421636
# 23:00:00   20.032085    8.173358   11.858727

# %%
import numpy as np
hourly_ticks = 4*60*60*np.arange(6)
by_time.plot(xticks=hourly_ticks,style = [':','--','-'])
# Out:
# <AxesSubplot:xlabel='time'>

# %%
hourly_ticks
# Out:
# array([    0, 14400, 28800, 43200, 57600, 72000])

# %%
by_weekday = data.groupby(data.index.dayofweek).mean()
by_weekday
# Out:
#            Total       East       West
# Date
# 0     128.726373  57.028529  71.697843
# 1     137.328839  61.107031  76.221808
# 2     136.565683  60.798651  75.767032
# 3     129.784665  58.152810  71.631855
# 4     117.517111  52.618209  64.898902
# 5      65.010049  32.414216  32.595833
# 6      62.526930  31.607574  30.919356

# %%
by_weekday.index = ['Mon','Tues','Wed','Thurs','Fri','Sat','Sun']
by_weekday.plot(style=[':','--','-'])
# Out:
# <AxesSubplot:>

# %%
weekend = np.where(data.index.weekday<5,'Weekday','Weekend')
by_time = data.groupby([weekend,data.index.time]).mean()

# %%
data.index
# Out:
# DatetimeIndex(['2019-11-01 00:00:00', '2019-11-01 01:00:00',
#                '2019-11-01 02:00:00', '2019-11-01 03:00:00',
#                '2019-11-01 04:00:00', '2019-11-01 05:00:00',
#                '2019-11-01 06:00:00', '2019-11-01 07:00:00',
#                '2019-11-01 08:00:00', '2019-11-01 09:00:00',
#                ...
#                '2021-06-30 14:00:00', '2021-06-30 15:00:00',
#                '2021-06-30 16:00:00', '2021-06-30 17:00:00',
#                '2021-06-30 18:00:00', '2021-06-30 19:00:00',
#                '2021-06-30 20:00:00', '2021-06-30 21:00:00',
#                '2021-06-30 22:00:00', '2021-06-30 23:00:00'],
#               dtype='datetime64[ns]', name='Date', length=142886, freq=None)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1,2,figsize=(14,5))
by_time.loc['Weekday'].plot(ax=ax[0],title='Weekdays',style=[':','--','-'])
by_time.loc['Weekend'].plot(ax=ax[1],title='Weekends',style=[':','--','-'])
# Out:
# <AxesSubplot:title={'center':'Weekends'}, xlabel='time'>
